# %%
import pandas as pd 
import numpy as np
import requests

# %%
# read my 1+ StreamingHistory files (depending on how)
df_stream0 = pd.read_json('StreamingHistory0.json')
df_stream1 = pd.read_json('StreamingHistory1.json')

# merge streaming dataframes
df_stream = pd.concat([df_stream0,df_stream1])

# create a 'uniqueID' for each song by combining the fields 'artistName' and 'trackName'
df_stream['UniqueID'] = df_stream['artistName']+":"+df_stream['trackName']

df_stream.head()
# Out:
#             endTime    artistName                    trackName  msPlayed  \
# 0  2022-07-09 12:19          Kygo                  Higher Love     11730
# 1  2022-07-09 12:19         Drake                 Falling Back     32810
# 2  2022-07-10 09:00  Dirtyphonics  Stage Divers - Original Mix     22506
# 3  2022-07-10 09:04         Lorde                     Supercut    277506
# 4  2022-07-10 09:29          Kygo               Stole the Show    143497
#
#                                    UniqueID
# 0                          Kygo:Higher Love
# 1                        Drake:Falling Back
# 2  Dirtyphonics:Stage Divers - Original Mix
# 3                            Lorde:Supercut
# 4                       Kygo:Stole the Show

# %%
# # read my edited Library json file into a pandas dataframe
# PATH_LIB = '/home/mijin/code/data-pipeline/dags/hive/mijin/spotify/YourLibrary.json'
# df_library = pd.read_json(PATH_LIB)

# # add UniqueID column (same as above)
# df_library['UniqueID'] = df_library['artist'] + ":" + df_library['track']

# # add column with track URI stripped of 'spotify:track:'
# new = df_library["uri"].str.split(":", expand=True)
# df_library['track_uri'] = new[2]

# df_library.head()

# %%
import json
import os
PATH_LIB = '/home/mijin/code/data-pipeline/dags/hive/mijin/spotify/YourLibrary.json'

# read the json file
with open(PATH_LIB, 'r') as file:
    data = json.load(file)

# function to recursively print all keys
def extract_unique_keys(data):
    unique_keys = set()
    if isinstance(data, dict):
        for key, value in data.items():
             unique_keys.add(key)
             unique_keys.update(extract_unique_keys(value))
    elif isinstance(data, list):
        for item in data:
            if isinstance(item, dict):
                unique_keys.update(extract_unique_keys(item))
    return unique_keys

# extract unique keys within each first-level key
unique_keys_per_key = {}
for key, value in data.items():
    unique_keys = extract_unique_keys(value)
    unique_keys_per_key[key] = unique_keys

# print the unique keys within each first-level key
for key, unique_keys in unique_keys_per_key.items():
    print(f"Unique keys in '{key}' :")
    for unique_key in unique_keys:
        print(unique_key)
    print()
# Out:
# Unique keys in 'tracks' :
# uri
# artist
# album
# track
#
# Unique keys in 'albums' :
# uri
# album
# artist
#
# Unique keys in 'shows' :
# publisher
# uri
# name
#
# Unique keys in 'episodes' :
# show
# uri
# name
#
# Unique keys in 'bannedTracks' :
#
# Unique keys in 'artists' :
# uri
# name
#
# Unique keys in 'bannedArtists' :
#
# Unique keys in 'other' :

# %%
# create a directory to store the divided datasets
output_dir = './divided_datasets'
os.makedirs(output_dir, exist_ok=True)

# divide the json dataset along the first-level key
for key, value in data.items():
    output_path = os.path.join(output_dir, f'{key}.json')
    with open(output_path, 'w') as output_file:
        json.dump(value, output_file, indent=4)

    print(f"Dataset for key '{key}' is saved to '{output_path}'")
# Out:
# Dataset for key 'tracks' is saved to './divided_datasets/tracks.json'
# Dataset for key 'albums' is saved to './divided_datasets/albums.json'
# Dataset for key 'shows' is saved to './divided_datasets/shows.json'
# Dataset for key 'episodes' is saved to './divided_datasets/episodes.json'
# Dataset for key 'bannedTracks' is saved to './divided_datasets/bannedTracks.json'
# Dataset for key 'artists' is saved to './divided_datasets/artists.json'
# Dataset for key 'bannedArtists' is saved to './divided_datasets/bannedArtists.json'
# Dataset for key 'other' is saved to './divided_datasets/other.json'

# %%
# read my edited track_library json file into a pandas dataframe
df_library = pd.read_json('./divided_datasets/tracks.json')

# add UniqueID column (same as above)
df_library['UniqueID'] = df_library['artist'] + ":" + df_library['track']

# add column with track URI stripped of 'spotify:track:'
new = df_library["uri"].str.split(":", expand = True)
df_library['track_uri'] = new[2]

df_library.head()
# Out:
#               artist                                              album  \
# 0       John De Sohn                                         Looking Up
# 1      Ouai Stéphane                                          Ouai ouai
# 2              Diplo  Diplo Presents Thomas Wesley: Chapter 1 - Snak...
# 3     Boombox Cartel                                         All I Want
# 4  Caroline Polachek                                               Pang
#
#                                track                                   uri  \
# 0                         Looking Up  spotify:track:4GvHfRUyNfNz86FbnDThDl
# 1      Bonjour c'est Stéphane encore  spotify:track:6q79iFTPE7eLM0Z7EEBQEV
# 2       Lonely (with Jonas Brothers)  spotify:track:6eXFl418w8hsxKcLgv1jwJ
# 3                         All I Want  spotify:track:1TFljRRw6jLg0qGP1Qa1Gc
# 4  So Hot You're Hurting My Feelings  spotify:track:5B6Kjha6RRIMWGN7zGsAaT
#
#                                             UniqueID               track_uri
# 0                            John De Sohn:Looking Up  4GvHfRUyNfNz86FbnDThDl
# 1        Ouai Stéphane:Bonjour c'est Stéphane encore  6q79iFTPE7eLM0Z7EEBQEV
# 2                 Diplo:Lonely (with Jonas Brothers)  6eXFl418w8hsxKcLgv1jwJ
# 3                          Boombox Cartel:All I Want  1TFljRRw6jLg0qGP1Qa1Gc
# 4  Caroline Polachek:So Hot You're Hurting My Fee...  5B6Kjha6RRIMWGN7zGsAaT

# %%
# create final dict as a copy df_stream
df_tableau = df_stream.copy()

# add column checking if streamed song is in library
# not used in this project but could be helpful for cool visualizations
df_tableau['InLibrary'] = np.where(df_tableau['UniqueID'].isin(df_library['UniqueID'].tolist()),1,0)

# left join with df_library on UniqueID to bring in album and track_uri
df_tableau = pd.merge(df_tableau, df_library[['album', 'UniqueID', 'track_uri']], how='left', on=['UniqueID'])

df_tableau.head(50)
# Out:
#              endTime                     artistName  \
# 0   2022-07-09 12:19                           Kygo
# 1   2022-07-09 12:19                          Drake
# 2   2022-07-10 09:00                   Dirtyphonics
# 3   2022-07-10 09:04                          Lorde
# 4   2022-07-10 09:29                           Kygo
# 5   2022-07-10 09:32                       Mr. Oizo
# 6   2022-07-10 09:36                       Mr. Oizo
# 7   2022-07-10 09:40                          Gater
# 8   2022-07-10 09:45                  Ouai Stéphane
# 9   2022-07-10 09:48                    Handbraekes
# 10  2022-07-10 09:52                         Glover
# 11  2022-07-10 09:57                  Iñigo Montoya
# 12  2022-07-10 10:00                       Mr. Oizo
# 13  2022-07-10 10:05               Teenage Bad Girl
# 14  2022-07-10 10:10  Jackson And His Computer Band
# 15  2022-07-10 10:13                    Handbraekes
# 16  2022-07-10 10:18                   Grand Soleil
# 17  2022-07-10 10:23                        You Man
# 18  2022-07-10 10:27                      Daft Punk
# 19  2022-07-10 10:30                       Mr. Oizo
# 20  2022-07-10 10:34            Simian Mobile Disco
# 21  2022-07-10 10:38                  Birdy Nam Nam
# 22  2022-07-10 10:42                         Danger
# 23  2022-07-10 10:45                      The Shoes
# 24  2022-07-10 10:48                       Siriusmo
# 25  2022-07-10 10:54          The Chemical Brothers
# 26  2022-07-10 10:58                       Mr. Oizo
# 27  2022-07-10 11:03                       Mr Flash
# 28  2022-07-10 11:07                   Audio Bullys
# 29  2022-07-10 11:12                            LFO
# 30  2022-07-11 06:42                    Mala Sangre
# 31  2022-07-11 06:45                        You Man
# 32  2022-07-11 06:46               Salut C'est Cool
# 33  2022-07-11 06:54                       Mr. Oizo
# 34  2022-07-11 06:55                Imagine Dragons
# 35  2022-07-11 06:58                  Little Giants
# 36  2022-07-11 07:01                   John De Sohn
# 37  2022-07-11 07:04                          Davai
# 38  2022-07-11 07:07                  Lucas & Steve
# 39  2022-07-11 07:10                        Hogland
# 40  2022-07-11 07:13                    Bassjackers
# 41  2022-07-11 07:16                  Lucas & Steve
# 42  2022-07-11 07:19                      Y.V.E. 48
# 43  2022-07-11 07:22                       Syn Cole
# 44  2022-07-11 07:26                      Klingande
# 45  2022-07-11 07:28                GAMPER & DADONI
# 46  2022-07-11 07:31                    Dash Berlin
# 47  2022-07-11 07:35                           Vice
# 48  2022-07-11 07:39                         OCEANS
# 49  2022-07-11 07:42                           Kygo
#
#                                             trackName  msPlayed  \
# 0                                         Higher Love     11730
# 1                                        Falling Back     32810
# 2                         Stage Divers - Original Mix     22506
# 3                                            Supercut    277506
# 4                                      Stole the Show    143497
# 5                                             Positif    171120
# 6                                          The Church    212681
# 7                                               Taboo    259000
# 8                                           Ouai ouai    250909
# 9                                           Callgurls    195037
# 10      Everybody Loves Balenciaga - Extended Version    260160
# 11                                               .E.S    300268
# 12                                            Machyne    188751
# 13                              USB Dick (Plug Me In)    244106
# 14                                             Arp #1    307999
# 15                                            The Qat    210784
# 16                                        Human Error    281987
# 17                                          Everybody    277241
# 18                  Human After All - SebastiAn Remix    287640
# 19                            Ruhe (feat. Boys Noize)    159560
# 20                               Hustler - Radio Edit    224666
# 21                                          No J No P    231946
# 22                                               4:30    271946
# 23                                            America    148533
# 24                                                EGO    217358
# 25                                        Do It Again    332973
# 26                                         Pharmacist    225293
# 27                                              Flesh    343348
# 28                                      We Don't Care    210800
# 29                                              Freak    303546
# 30                              Fear is your Only God     89845
# 31                                         Who We Are    175578
# 32                                     Salam Aleykoum     28174
# 33                                           Flip Bat    181141
# 34                                             Demons      8070
# 35    Lately (Love, Love, Love) - Kav Verhouzer Remix    200291
# 36                                         Looking Up    170666
# 37                                               Loco    176613
# 38                              Perfect (feat. Haris)    176517
# 39                                       Got You Babe    190606
# 40             These Heights (feat. Caroline Pennell)    184946
# 41                                  Give Me Your Love    202530
# 42                               Still Think About It    179718
# 43                           Side By Side (with MKLA)    153870
# 44                                           Losing U    217015
# 45                                          My Lovin'    150023
# 46                                    We Don't Belong    186363
# 47  Find A Way (Kayliox Remix) [feat. Gary Pine & ...    225823
# 48                                  Cold Ain't For Me    205812
# 49                    It Ain't Me (with Selena Gomez)    220780
#
#                                              UniqueID  InLibrary  \
# 0                                    Kygo:Higher Love          0
# 1                                  Drake:Falling Back          0
# 2            Dirtyphonics:Stage Divers - Original Mix          0
# 3                                      Lorde:Supercut          0
# 4                                 Kygo:Stole the Show          0
# 5                                    Mr. Oizo:Positif          0
# 6                                 Mr. Oizo:The Church          0
# 7                                         Gater:Taboo          1
# 8                             Ouai Stéphane:Ouai ouai          0
# 9                               Handbraekes:Callgurls          0
# 10  Glover:Everybody Loves Balenciaga - Extended V...          1
# 11                                 Iñigo Montoya:.E.S          0
# 12                                   Mr. Oizo:Machyne          0
# 13             Teenage Bad Girl:USB Dick (Plug Me In)          0
# 14               Jackson And His Computer Band:Arp #1          0
# 15                                Handbraekes:The Qat          0
# 16                           Grand Soleil:Human Error          0
# 17                                  You Man:Everybody          0
# 18        Daft Punk:Human After All - SebastiAn Remix          0
# 19                   Mr. Oizo:Ruhe (feat. Boys Noize)          0
# 20           Simian Mobile Disco:Hustler - Radio Edit          0
# 21                            Birdy Nam Nam:No J No P          0
# 22                                        Danger:4:30          0
# 23                                  The Shoes:America          0
# 24                                       Siriusmo:EGO          0
# 25                  The Chemical Brothers:Do It Again          0
# 26                                Mr. Oizo:Pharmacist          0
# 27                                     Mr Flash:Flesh          0
# 28                         Audio Bullys:We Don't Care          0
# 29                                          LFO:Freak          0
# 30                  Mala Sangre:Fear is your Only God          0
# 31                                 You Man:Who We Are          0
# 32                    Salut C'est Cool:Salam Aleykoum          0
# 33                                  Mr. Oizo:Flip Bat          0
# 34                             Imagine Dragons:Demons          0
# 35  Little Giants:Lately (Love, Love, Love) - Kav ...          0
# 36                            John De Sohn:Looking Up          1
# 37                                         Davai:Loco          0
# 38                Lucas & Steve:Perfect (feat. Haris)          0
# 39                               Hogland:Got You Babe          0
# 40  Bassjackers:These Heights (feat. Caroline Penn...          0
# 41                    Lucas & Steve:Give Me Your Love          0
# 42                     Y.V.E. 48:Still Think About It          0
# 43                  Syn Cole:Side By Side (with MKLA)          0
# 44                                 Klingande:Losing U          0
# 45                          GAMPER & DADONI:My Lovin'          0
# 46                        Dash Berlin:We Don't Belong          0
# 47  Vice:Find A Way (Kayliox Remix) [feat. Gary Pi...          1
# 48                           OCEANS:Cold Ain't For Me          0
# 49               Kygo:It Ain't Me (with Selena Gomez)          0
#
#                                                 album               track_uri
# 0                                                 NaN                     NaN
# 1                                                 NaN                     NaN
# 2                                                 NaN                     NaN
# 3                                                 NaN                     NaN
# 4                                                 NaN                     NaN
# 5                                                 NaN                     NaN
# 6                                                 NaN                     NaN
# 7                    Taboo (feat. Chesty Morganstein)  5CVOeNkatHhW7Uc7M7zffK
# 8                                                 NaN                     NaN
# 9                                                 NaN                     NaN
# 10                         Everybody Loves Balenciaga  2KOZg6fEDvhsvGySfhaW9h
# 11                                                NaN                     NaN
# 12                                                NaN                     NaN
# 13                                                NaN                     NaN
# 14                                                NaN                     NaN
# 15                                                NaN                     NaN
# 16                                                NaN                     NaN
# 17                                                NaN                     NaN
# 18                                                NaN                     NaN
# 19                                                NaN                     NaN
# 20                                                NaN                     NaN
# 21                                                NaN                     NaN
# 22                                                NaN                     NaN
# 23                                                NaN                     NaN
# 24                                                NaN                     NaN
# 25                                                NaN                     NaN
# 26                                                NaN                     NaN
# 27                                                NaN                     NaN
# 28                                                NaN                     NaN
# 29                                                NaN                     NaN
# 30                                                NaN                     NaN
# 31                                                NaN                     NaN
# 32                                                NaN                     NaN
# 33                                                NaN                     NaN
# 34                                                NaN                     NaN
# 35                                                NaN                     NaN
# 36                                         Looking Up  4GvHfRUyNfNz86FbnDThDl
# 37                                                NaN                     NaN
# 38                                                NaN                     NaN
# 39                                                NaN                     NaN
# 40                                                NaN                     NaN
# 41                                                NaN                     NaN
# 42                                                NaN                     NaN
# 43                                                NaN                     NaN
# 44                                                NaN                     NaN
# 45                                                NaN                     NaN
# 46                                                NaN                     NaN
# 47  Find A Way (Kayliox Remix) [feat. Gary Pine & ...  0puff9xYitfD3Mh1wigdFV
# 48                                                NaN                     NaN
# 49                                                NaN                     NaN

# %%
# save my IDs from new project in Spotify Developer Dashboard
CLIENT_ID = 'f014be6f3056430ba3a886bab188611a'
CLIENT_SECRET = 'e2b7838194cb4fb8b9b6f1f6da57ab2f'

# generate access token

# authentication URL
AUTH_URL = 'https://accounts.spotify.com/api/token'

# POST
auth_response = requests.post(AUTH_URL, {
    'grant_type': 'client_credentials',
    'client_id': CLIENT_ID,
    'client_secret' : CLIENT_SECRET 
})

# convert the response to JSON
auth_response_data = auth_response.json()

# save the access token
access_token = auth_response_data['access_token']

# used for authenticating all API calls
headers = {'Authorization': 'Bearer {token}'.format(token=access_token)}

# base URL of all Spotify API endpoints
BASE_URL = 'https://api.spotify.com/v1/'

# %%
# create blank dictionary to store track URI, artist URI, and genres
dict_genre = {}

# convert track_uri column to an iterable list
track_uris = df_library['track_uri'].to_list()

# loop through track URIs and pull artist URI using the API,
# then use artist URI to pull genres associated with that artist
# store all these in a dictionary
for t_uri in track_uris:

    dict_genre[t_uri] = {'artist_uri': "", "genres":[]}
    
    r = requests.get(BASE_URL + 'tracks/' + t_uri, headers=headers)
    r = r.json()
    a_uri = r['artists'][0]['uri'].split(':')[2]
    dict_genre[t_uri]['artist_uri'] = a_uri
    
    s = requests.get(BASE_URL + 'artists/' + a_uri, headers=headers)
    s = s.json()
    dict_genre[t_uri]['genres'] = s['genres']

# convert dictionary into dataframe with track_uri as the first column
df_genre = pd.DataFrame.from_dict(dict_genre, orient='index')
df_genre.insert(0, 'track_uri', df_genre.index)
df_genre.reset_index(inplace=True, drop=True)

df_genre.head(10)
# Out:
#                 track_uri              artist_uri  \
# 0  4GvHfRUyNfNz86FbnDThDl  3TVjdmhfFoYJLgBEkkZTBm
# 1  6q79iFTPE7eLM0Z7EEBQEV  2PLiFvOw5jPlHoGoxjeeaf
# 2  6eXFl418w8hsxKcLgv1jwJ  5fMUXHkw8R8eOP2RNVYEZX
# 3  1TFljRRw6jLg0qGP1Qa1Gc  4m1yRHUMhvB8gKAJTjK4kO
# 4  5B6Kjha6RRIMWGN7zGsAaT  4Ge8xMJNwt6EEXOzVXju9a
# 5  324Jd5N9usVLnRluow8ojb  6vqMDhoigg5btfdPsPTVFt
# 6  05IyD7K9Q4lgu8W4Xfi9Lx  1ikID9RZZMvkuBGDWrqajq
# 7  3unpulZnIiKRZ4MCymHfXx  63XBtGSEZINSyXylZxEUbv
# 8  5d8a5B6RlYnquvR4X4OIrX  69GGBxA162lTqCwzJG5jLp
# 9  2CgOd0Lj5MuvOqzqdaAXtS  3dz0NnIZhtKKeXZxLOxCam
#
#                                               genres
# 0  [deep pop edm, pop dance, swedish tropical house]
# 1                                                 []
# 2        [edm, electro house, moombahton, pop dance]
# 3          [brostep, electro house, electronic trap]
# 4    [art pop, escape room, indie pop, indietronica]
# 5  [australian indie, australian indie rock, bris...
# 6  [future bass, pop edm, swedish electropop, vap...
# 7                                  [alternative r&b]
# 8                                  [electropop, pop]
# 9  [complextro, edm, electro house, pop dance, pr...

# %%
df_genre_expanded = df_genre.explode('genres')
df_genre_expanded.head()
# Out:
#                 track_uri              artist_uri                  genres
# 0  4GvHfRUyNfNz86FbnDThDl  3TVjdmhfFoYJLgBEkkZTBm            deep pop edm
# 0  4GvHfRUyNfNz86FbnDThDl  3TVjdmhfFoYJLgBEkkZTBm               pop dance
# 0  4GvHfRUyNfNz86FbnDThDl  3TVjdmhfFoYJLgBEkkZTBm  swedish tropical house
# 1  6q79iFTPE7eLM0Z7EEBQEV  2PLiFvOw5jPlHoGoxjeeaf                     NaN
# 2  6eXFl418w8hsxKcLgv1jwJ  5fMUXHkw8R8eOP2RNVYEZX                     edm

# %%
# save df_tableau and df_genre_expanded as csv files that we can visualization
df_tableau.to_csv('MySpotifyDataTable.csv')
df_genre_expanded.to_csv('GenresExpandedTable.csv')

print('done')
# Out:
# done
